# %% [markdown]
# # IS NULL - 나이 정보가 없는 회원 수 구하기

# %% [markdown]
# ## 문제

# %% [markdown]
# ![image](https://velog.velcdn.com/images/tkddud95920/post/64aa36d2-9b5e-492d-ac71-dacb9799e51e/image.png)

# %% [markdown]
# ## 접근

# %%
# select절에서 회원 count
# 나이가 null값인 것만 where로 필터링

# %% [markdown]
# ## 풀이

# %%
"""
SELECT COUNT(user_id) AS users
FROM user_info
WHERE age IS NULL;
"""
