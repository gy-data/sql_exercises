# %% [markdown]
# # IS NULL - 이름이 있는 동물의 아이디

# %% [markdown]
# ## 문제

# %% [markdown]
# ![image](https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdn%2FLsEuJ%2FbtrwonjzYFL%2F9AtcQdrPyEgKf3p8zKbu21%2Fimg.png)

# %% [markdown]
# ## 접근

# %%
# 이름이 NULL값인 데이터를 WHERE로 필터링
# ID에 따라 asc 정렬

# %% [markdown]
# ## 풀이

# %%
"""
SELECT animal_id
FROM animal_ins
WHERE name IS NOT NULL
ORDER BY animal_id;
"""
